# %% [markdown]
# # Project:
# Analyze Supermarket Data Across the Country - Company XYZ

# %% [markdown]
# # Step 1 - Loading the Dataset
# * Correct use of pathname pattern - glob
# * Combine all the files generated in a list and export to a CSV.

# %%
import pandas as pd
import numpy as np
from glob import glob
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
files = sorted(glob('*_Branch.csv'))
files
# Out:
# ['Abuja_Branch.csv', 'Lagos_Branch.csv', 'Port_Harcourt_Branch.csv']

# %%
#Combine all the files generated in a list and export to a CSV
csv_file = pd.concat((pd.read_csv(file) for file in files), ignore_index=True)
csv_file
# Out:
#       Invoice ID Branch           City Customer type  Gender  \
# 0    692-92-5582      B          Abuja        Member  Female
# 1    351-62-0822      B          Abuja        Member  Female
# 2    529-56-3974      B          Abuja        Member    Male
# 3    299-46-1805      B          Abuja        Member  Female
# 4    319-50-3348      B          Abuja        Normal  Female
# ..           ...    ...            ...           ...     ...
# 995  148-41-7930      C  Port Harcourt        Normal    Male
# 996  189-40-5216      C  Port Harcourt        Normal    Male
# 997  267-62-7380      C  Port Harcourt        Member    Male
# 998  652-49-6720      C  Port Harcourt        Member  Female
# 999  233-67-5758      C  Port Harcourt        Normal    Male
#
#                Product line  Unit price  Quantity    Tax 5%      Total  \
# 0        Food and beverages     19742.4         3   2961.36   62188.56
# 1       Fashion accessories      5212.8         4   1042.56   21893.76
# 2    Electronic accessories      9183.6         4   1836.72   38571.12
# 3         Sports and travel     33739.2         6  10121.76  212556.96
# 4        Home and lifestyle     14508.0         2   1450.80   30466.80
# ..                      ...         ...       ...       ...        ...
# 995       Health and beauty     35985.6         7  12594.96  264494.16
# 996  Electronic accessories     34693.2         7  12142.62  254995.02
# 997  Electronic accessories     29642.4        10  14821.20  311245.20
# 998  Electronic accessories     21942.0         1   1097.10   23039.10
# 999       Health and beauty     14526.0         1    726.30   15252.30
#
#           Date   Time Payment      cogs  gross margin percentage  \
# 0    2/20/2019  13:27    Card   59227.2                 4.761905
# 1     2/6/2019  18:07    Epay   20851.2                 4.761905
# 2     3/9/2019  17:03    Cash   36734.4                 4.761905
# 3    1/15/2019  16:19    Cash  202435.2                 4.761905
# 4    3/11/2019  15:30    Epay   29016.0                 4.761905
# ..         ...    ...     ...       ...                      ...
# 995  1/23/2019  10:33    Cash  251899.2                 4.761905
# 996   1/9/2019  11:40    Cash  242852.4                 4.761905
# 997  3/29/2019  19:12    Epay  296424.0                 4.761905
# 998  2/18/2019  11:40    Epay   21942.0                 4.761905
# 999  1/29/2019  13:46    Epay   14526.0                 4.761905
#
#      gross income  Rating
# 0         2961.36     5.9
# 1         1042.56     4.5
# 2         1836.72     6.8
# 3        10121.76     4.5
# 4         1450.80     4.4
# ..            ...     ...
# 995      12594.96     6.1
# 996      12142.62     6.0
# 997      14821.20     4.3
# 998       1097.10     5.9
# 999        726.30     6.2
#
# [1000 rows x 17 columns]

# %% [markdown]
# ## Step 2 - Data Exploration
# - Use the head() method to view first few rows of the dataset
# - Check the number of rows and columns present in the data using the shape attribute.
# - Generate the names of the columns using the columns attribute.
# - Use describe function to generate the statistical summary of the dataframe
# - Use meaningful sentences to describe findings from the data statistical summary
# - Use of correct method to check for Missing values
# - Check the information of the DataFrame using the info method.

# %%
csv_file.to_csv( "csv_file.csv", index=False, encoding='utf-8-sig')

# %%
#Use the head() method to view first few rows of the dataset
df = pd.read_csv('csv_file.csv')
df.head()
# Out:
#     Invoice ID Branch   City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1  351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2  529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3  299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4  319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
#
#    Unit price  Quantity    Tax 5%      Total       Date   Time Payment  \
# 0     19742.4         3   2961.36   62188.56  2/20/2019  13:27    Card
# 1      5212.8         4   1042.56   21893.76   2/6/2019  18:07    Epay
# 2      9183.6         4   1836.72   38571.12   3/9/2019  17:03    Cash
# 3     33739.2         6  10121.76  212556.96  1/15/2019  16:19    Cash
# 4     14508.0         2   1450.80   30466.80  3/11/2019  15:30    Epay
#
#        cogs  gross margin percentage  gross income  Rating
# 0   59227.2                 4.761905       2961.36     5.9
# 1   20851.2                 4.761905       1042.56     4.5
# 2   36734.4                 4.761905       1836.72     6.8
# 3  202435.2                 4.761905      10121.76     4.5
# 4   29016.0                 4.761905       1450.80     4.4

# %%
#Check the number of rows and columns present in the data using the shape attribute.
df.shape
# Out:
# (1000, 17)

# %% [markdown]
# Comment:
# * There are 1000 rows and 17 columns inthe dataset

# %%
df.tail()
# Out:
#       Invoice ID Branch           City Customer type  Gender  \
# 995  148-41-7930      C  Port Harcourt        Normal    Male
# 996  189-40-5216      C  Port Harcourt        Normal    Male
# 997  267-62-7380      C  Port Harcourt        Member    Male
# 998  652-49-6720      C  Port Harcourt        Member  Female
# 999  233-67-5758      C  Port Harcourt        Normal    Male
#
#                Product line  Unit price  Quantity    Tax 5%      Total  \
# 995       Health and beauty     35985.6         7  12594.96  264494.16
# 996  Electronic accessories     34693.2         7  12142.62  254995.02
# 997  Electronic accessories     29642.4        10  14821.20  311245.20
# 998  Electronic accessories     21942.0         1   1097.10   23039.10
# 999       Health and beauty     14526.0         1    726.30   15252.30
#
#           Date   Time Payment      cogs  gross margin percentage  \
# 995  1/23/2019  10:33    Cash  251899.2                 4.761905
# 996   1/9/2019  11:40    Cash  242852.4                 4.761905
# 997  3/29/2019  19:12    Epay  296424.0                 4.761905
# 998  2/18/2019  11:40    Epay   21942.0                 4.761905
# 999  1/29/2019  13:46    Epay   14526.0                 4.761905
#
#      gross income  Rating
# 995      12594.96     6.1
# 996      12142.62     6.0
# 997      14821.20     4.3
# 998       1097.10     5.9
# 999        726.30     6.2

# %%
#Total number of rows
df.shape[0]
# Out:
# 1000

# %%
#Total number of columns
df.shape[-1]
# Out:
# 17

# %%
#Generate the names of the columns using the columns attribute
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['Invoice ID',
#  'Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Unit price',
#  'Quantity',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'Payment',
#  'cogs',
#  'gross margin percentage',
#  'gross income',
#  'Rating']

# %%
#Use describe function to generate the statistical summary of the dataframe
df.describe()
# Out:
#          Unit price     Quantity        Tax 5%          Total           cogs  \
# count   1000.000000  1000.000000   1000.000000    1000.000000    1000.000000
# mean   20041.966800     5.510000   5536.572840  116268.029640  110731.456800
# std     9538.066205     2.923431   4215.177173   88518.720636   84303.543463
# min     3628.800000     1.000000    183.060000    3844.260000    3661.200000
# 25%    11835.000000     3.000000   2132.955000   44792.055000   42659.100000
# 50%    19882.800000     5.000000   4351.680000   91385.280000   87033.600000
# 75%    28056.600000     8.000000   8080.290000  169686.090000  161605.800000
# max    35985.600000    10.000000  17874.000000  375354.000000  357480.000000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00   5536.572840     6.97270
# std               6.131498e-14   4215.177173     1.71858
# min               4.761905e+00    183.060000     4.00000
# 25%               4.761905e+00   2132.955000     5.50000
# 50%               4.761905e+00   4351.680000     7.00000
# 75%               4.761905e+00   8080.290000     8.50000
# max               4.761905e+00  17874.000000    10.00000

# %% [markdown]
# Comments:
# * Average for:
#     * Unit price is 20041.966800
#     * Quantity is 5.51
#     * Tax 5% is 5536.572840
#     * gross margin percentage is 4.761905e+00
#     * gross income is 5536.572840
#     * Rating 6.9727
# * There is no missing values in the dataset
# * There are 1000 row and 17 columns
# * The min rating is 4
# * The max rating is 10
# * gross margin percentage has the minimum std while Total has the highest
# * cogs has the highest average 110731.456800
# * gross margin percentage has the least average
# * 25% signifies first quartile
# * 75% signifies 3rd quartile and the highest 3rd quartile is Total while gross margin percentage has the least
# * 50% means median(middle)

# %%
#Highest average
df.describe().mean().max()
# Out:
# 111356.05440954374

# %%
df.columns.max()
# Out:
# 'gross margin percentage'

# %%
#Extract the minimum std
df.std().min()
# Out:
# C:\Users\Saheed\AppData\Local\Temp\ipykernel_7624\3538978034.py:2: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std().min()
# 6.131497611557303e-14

# %%
df.std()
# Out:
# C:\Users\Saheed\AppData\Local\Temp\ipykernel_7624\3390915376.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# Unit price                 9.538066e+03
# Quantity                   2.923431e+00
# Tax 5%                     4.215177e+03
# Total                      8.851872e+04
# cogs                       8.430354e+04
# gross margin percentage    6.131498e-14
# gross income               4.215177e+03
# Rating                     1.718580e+00
# dtype: float64

# %%
#Maximum std
df.std().max()
# Out:
# C:\Users\Saheed\AppData\Local\Temp\ipykernel_7624\2203905562.py:2: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std().max()
# 88518.72063634984

# %%
#Minimum std
df.std().min()
# Out:
# C:\Users\Saheed\AppData\Local\Temp\ipykernel_7624\2966986923.py:2: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std().min()
# 6.131497611557303e-14

# %%
#Maximum average
df.mean().max()
# Out:
# C:\Users\Saheed\AppData\Local\Temp\ipykernel_7624\2987802571.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean().max()
# 116268.02964000002

# %%
#Minimum average
df.mean().min()
# Out:
# C:\Users\Saheed\AppData\Local\Temp\ipykernel_7624\1706475440.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean().min()
# 4.761904762

# %%
#The top 10 highest number of gross income
df.nlargest(10, 'gross income')
# Out:
#       Invoice ID Branch           City Customer type  Gender  \
# 790  860-79-0874      C  Port Harcourt        Member  Female
# 386  687-47-8271      A          Lagos        Normal    Male
# 862  283-26-5248      C  Port Harcourt        Member  Female
# 903  751-41-9720      C  Port Harcourt        Normal    Male
# 331  303-96-2227      B          Abuja        Normal  Female
# 261  744-16-7898      B          Abuja        Normal  Female
# 818  271-88-8734      C  Port Harcourt        Member  Female
# 733  234-65-2137      C  Port Harcourt        Normal    Male
# 793  554-42-2417      C  Port Harcourt        Normal  Female
# 480  325-77-6186      A          Lagos        Member  Female
#
#             Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 790  Fashion accessories     35748.0        10  17874.0  375354.0  2/15/2019
# 386  Fashion accessories     35632.8        10  17816.4  374144.4   2/8/2019
# 862   Food and beverages     35467.2        10  17733.6  372405.6  1/30/2019
# 903   Home and lifestyle     35100.0        10  17550.0  368550.0  1/12/2019
# 331   Home and lifestyle     35056.8        10  17528.4  368096.4   3/2/2019
# 261   Home and lifestyle     35053.2        10  17526.6  368058.6  1/15/2019
# 818  Fashion accessories     34995.6        10  17497.8  367453.8   2/8/2019
# 733   Home and lifestyle     34408.8        10  17204.4  361292.4  1/16/2019
# 793    Sports and travel     34358.4        10  17179.2  360763.2   1/9/2019
# 480   Home and lifestyle     32634.0        10  16317.0  342657.0   3/8/2019
#
#       Time Payment      cogs  gross margin percentage  gross income  Rating
# 790  14:53    Card  357480.0                 4.761905       17874.0     6.6
# 386  16:20    Card  356328.0                 4.761905       17816.4     8.7
# 862  20:23    Epay  354672.0                 4.761905       17733.6     4.5
# 903  16:18    Epay  351000.0                 4.761905       17550.0     8.0
# 331  17:16    Epay  350568.0                 4.761905       17528.4     4.4
# 261  13:48    Card  350532.0                 4.761905       17526.6     4.9
# 818  13:00    Card  349956.0                 4.761905       17497.8     8.7
# 733  13:32    Cash  344088.0                 4.761905       17204.4     4.8
# 793  13:45    Cash  343584.0                 4.761905       17179.2     5.2
# 480  10:53    Epay  326340.0                 4.761905       16317.0     7.3

# %%
#Extract the top 5 cogs
df.nlargest(5, 'cogs')
# Out:
#       Invoice ID Branch           City Customer type  Gender  \
# 790  860-79-0874      C  Port Harcourt        Member  Female
# 386  687-47-8271      A          Lagos        Normal    Male
# 862  283-26-5248      C  Port Harcourt        Member  Female
# 903  751-41-9720      C  Port Harcourt        Normal    Male
# 331  303-96-2227      B          Abuja        Normal  Female
#
#             Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 790  Fashion accessories     35748.0        10  17874.0  375354.0  2/15/2019
# 386  Fashion accessories     35632.8        10  17816.4  374144.4   2/8/2019
# 862   Food and beverages     35467.2        10  17733.6  372405.6  1/30/2019
# 903   Home and lifestyle     35100.0        10  17550.0  368550.0  1/12/2019
# 331   Home and lifestyle     35056.8        10  17528.4  368096.4   3/2/2019
#
#       Time Payment      cogs  gross margin percentage  gross income  Rating
# 790  14:53    Card  357480.0                 4.761905       17874.0     6.6
# 386  16:20    Card  356328.0                 4.761905       17816.4     8.7
# 862  20:23    Epay  354672.0                 4.761905       17733.6     4.5
# 903  16:18    Epay  351000.0                 4.761905       17550.0     8.0
# 331  17:16    Epay  350568.0                 4.761905       17528.4     4.4

# %%
#Extract quantity less than 10
qu = df['Quantity'] < 10
qu.sum()
# Out:
# 881

# %%
#Extract how many female customers
female_no = df['Gender'] == 'Female'
female_no.sum()
# Out:
# 501

# %% [markdown]
# Comment:
# * There are 501 female customers in all the three cities

# %%
#Extract how many male customers
male_no = df['Gender'] == 'Male'
male_no.sum()
# Out:
# 499

# %% [markdown]
# Comment:
# * There are 501 male customers in all the three cities

# %%
#Extract how many customers used Cash as a method of payment
cash = df['Payment'] == 'Cash'
cash.sum()
print('There are {} customers used Card'.format(cash.sum()))
# Out:
# There are 344 customers used Card

# %%
#Extract how many customers used Cash as a method of payment
epay = df['Payment'] == 'Epay'
print('There are {} customers that used Card'.format(epay.sum()))
# Out:
# There are 345 customers that used Card

# %%
#Extract how many customers used Card as a method of payment
card = df['Payment'] == 'Card'
print('There are {} customers that used Card'.format(card.sum()))
# Out:
# There are 311 customers that used Card

# %%
#Extract how many customers used both Cash and Epay as a method of payment
cash_epay = df['Payment'] != 'Card'
print('There are {} customers that used Card and Epay'.format(cash_epay.sum()))
# Out:
# There are 689 customers that used Card and Epay

# %%
#Extract how many customers used both Cash and Epay as a method of payment
cash_card = df['Payment'] != 'Epay'
print('There are {} customers that used Card and Cash'.format(cash_card.sum()))
# Out:
# There are 655 customers that used Card and Cash

# %%
#Extract Rating below 5
rating = df['Rating'] < 5
print('There are {} rating below 5'.format(rating.sum()))
# Out:
# There are 153 rating below 5

# %%
#Extract Rating below 5
rating = df['Rating'] >= 5
print('There are {} rating above 5'.format(rating.sum()))
# Out:
# There are 847 rating above 5

# %%
df['Product line'].value_counts()
# Out:
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product line, dtype: int64

# %%
#Extract how many customers used Sports and line as product line
prod = df['Product line'] == 'Sports and travel'
prod.sum()
# Out:
# 166

# %%
#Extract how many customers used Health and beauty
prod = df['Product line'] == 'Health and beauty'
prod.sum()
# Out:
# 152

# %%
#Extract all the information of customer used home and lifestyle
df[df['Product line'] == 'Home and lifestyle']
# Out:
#       Invoice ID Branch           City Customer type  Gender  \
# 4    319-50-3348      B          Abuja        Normal  Female
# 6    273-16-6619      B          Abuja        Normal    Male
# 12   777-82-7220      B          Abuja        Member    Male
# 13   280-35-5823      B          Abuja        Member  Female
# 20   242-55-6721      B          Abuja        Normal    Male
# ..           ...    ...            ...           ...     ...
# 976  246-55-6923      C  Port Harcourt        Member  Female
# 977  838-02-1821      C  Port Harcourt        Member  Female
# 982  235-06-8510      C  Port Harcourt        Member    Male
# 987  373-88-1424      C  Port Harcourt        Member    Male
# 990  867-47-1948      C  Port Harcourt        Normal  Female
#
#            Product line  Unit price  Quantity   Tax 5%      Total       Date  \
# 4    Home and lifestyle     14508.0         2  1450.80   30466.80  3/11/2019
# 6    Home and lifestyle     11952.0         2  1195.20   25099.20  3/15/2019
# 12   Home and lifestyle     10843.2         8  4337.28   91082.88   3/3/2019
# 13   Home and lifestyle     31219.2         1  1560.96   32780.16  1/17/2019
# 20   Home and lifestyle      5817.6         2   581.76   12216.96   3/7/2019
# ..                  ...         ...       ...      ...        ...        ...
# 976  Home and lifestyle     12884.4         9  5797.98  121757.58  3/10/2019
# 977  Home and lifestyle      4582.8         2   458.28    9623.88  2/22/2019
# 982  Home and lifestyle     30859.2         3  4628.88   97206.48  1/24/2019
# 987  Home and lifestyle     12891.6         5  3222.90   67680.90   2/6/2019
# 990  Home and lifestyle      5688.0        10  2844.00   59724.00   1/9/2019
#
#       Time Payment      cogs  gross margin percentage  gross income  Rating
# 4    15:30    Epay   29016.0                 4.761905       1450.80     4.4
# 6    12:20    Card   23904.0                 4.761905       1195.20     4.4
# 12   13:01    Cash   86745.6                 4.761905       4337.28     7.7
# 13   18:45    Epay   31219.2                 4.761905       1560.96     7.9
# 20   11:49    Epay   11635.2                 4.761905        581.76     6.5
# ..     ...     ...       ...                      ...           ...     ...
# 976  15:06    Card  115959.6                 4.761905       5797.98     5.1
# 977  12:10    Card    9165.6                 4.761905        458.28     5.2
# 982  20:59    Epay   92577.6                 4.761905       4628.88     5.1
# 987  18:44    Epay   64458.0                 4.761905       3222.90     7.9
# 990  12:07    Cash   56880.0                 4.761905       2844.00     7.8
#
# [160 rows x 17 columns]

# %%
#Extract total number of customers used home and lifestyle
len(df[df['Product line'] == 'Home and lifestyle'])
# Out:
# 160

# %%
#Extract the top smallest 5 Tax
df.nsmallest(5, 'Tax 5%')
# Out:
#       Invoice ID Branch           City Customer type  Gender  \
# 947  784-21-9238      C  Port Harcourt        Member    Male
# 545  308-39-1707      A          Lagos        Normal  Female
# 752  279-62-1445      C  Port Harcourt        Member  Female
# 826  192-98-7397      C  Port Harcourt        Normal    Male
# 811  236-86-3015      C  Port Harcourt        Member    Male
#
#             Product line  Unit price  Quantity  Tax 5%    Total       Date  \
# 947    Sports and travel      3661.2         1  183.06  3844.26   2/7/2019
# 545  Fashion accessories      4352.4         1  217.62  4570.02  1/26/2019
# 752  Fashion accessories      4514.4         1  225.72  4740.12  2/21/2019
# 826  Fashion accessories      4600.8         1  230.04  4830.84   1/8/2019
# 811   Home and lifestyle      5032.8         1  251.64  5284.44   2/4/2019
#
#       Time Payment    cogs  gross margin percentage  gross income  Rating
# 947  14:15    Cash  3661.2                 4.761905        183.06     5.9
# 545  18:19    Card  4352.4                 4.761905        217.62     8.2
# 752  12:38    Cash  4514.4                 4.761905        225.72     8.2
# 826  14:11    Epay  4600.8                 4.761905        230.04     9.5
# 811  13:38    Epay  5032.8                 4.761905        251.64     9.8

# %%
#Extract the top highest 5 Tax
df.nlargest(5, 'Tax 5%')
# Out:
#       Invoice ID Branch           City Customer type  Gender  \
# 790  860-79-0874      C  Port Harcourt        Member  Female
# 386  687-47-8271      A          Lagos        Normal    Male
# 862  283-26-5248      C  Port Harcourt        Member  Female
# 903  751-41-9720      C  Port Harcourt        Normal    Male
# 331  303-96-2227      B          Abuja        Normal  Female
#
#             Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 790  Fashion accessories     35748.0        10  17874.0  375354.0  2/15/2019
# 386  Fashion accessories     35632.8        10  17816.4  374144.4   2/8/2019
# 862   Food and beverages     35467.2        10  17733.6  372405.6  1/30/2019
# 903   Home and lifestyle     35100.0        10  17550.0  368550.0  1/12/2019
# 331   Home and lifestyle     35056.8        10  17528.4  368096.4   3/2/2019
#
#       Time Payment      cogs  gross margin percentage  gross income  Rating
# 790  14:53    Card  357480.0                 4.761905       17874.0     6.6
# 386  16:20    Card  356328.0                 4.761905       17816.4     8.7
# 862  20:23    Epay  354672.0                 4.761905       17733.6     4.5
# 903  16:18    Epay  351000.0                 4.761905       17550.0     8.0
# 331  17:16    Epay  350568.0                 4.761905       17528.4     4.4

# %%
# Use of correct method to check for Missing values
df.isna().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %% [markdown]
# Comment:
# * From the above result, there is no missing value

# %%
#Check the information of the DataFrame using the info method
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
# dtypes: float64(7), int64(1), object(9)
# memory usage: 132.9+ KB

# %%
df.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %% [markdown]
# ### Step 3 - Dealing with DateTime Features
# - Use to_datetime() to convert the date column to datetime
# - Check the datatype to confirm if it's in datetime
# - Accurate conversion of the time column & prints appropriate data type
# - Accurate extraction of the Day, Month, Year & Hour features
# - The numbers of unique hours of sales in the supermarket are accurately determined.
# - Result that shows an array that contains the unique sales hours.

# %%
df.head()
# Out:
#     Invoice ID Branch   City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1  351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2  529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3  299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4  319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
#
#    Unit price  Quantity    Tax 5%      Total       Date   Time Payment  \
# 0     19742.4         3   2961.36   62188.56  2/20/2019  13:27    Card
# 1      5212.8         4   1042.56   21893.76   2/6/2019  18:07    Epay
# 2      9183.6         4   1836.72   38571.12   3/9/2019  17:03    Cash
# 3     33739.2         6  10121.76  212556.96  1/15/2019  16:19    Cash
# 4     14508.0         2   1450.80   30466.80  3/11/2019  15:30    Epay
#
#        cogs  gross margin percentage  gross income  Rating
# 0   59227.2                 4.761905       2961.36     5.9
# 1   20851.2                 4.761905       1042.56     4.5
# 2   36734.4                 4.761905       1836.72     6.8
# 3  202435.2                 4.761905      10121.76     4.5
# 4   29016.0                 4.761905       1450.80     4.4

# %%
#Use to_datetime() to convert the date object column to datetime
df['Date'] = pd.to_datetime(df['Date'])
df.head()
# Out:
#     Invoice ID Branch   City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1  351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2  529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3  299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4  319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
#
#    Unit price  Quantity    Tax 5%      Total       Date   Time Payment  \
# 0     19742.4         3   2961.36   62188.56 2019-02-20  13:27    Card
# 1      5212.8         4   1042.56   21893.76 2019-02-06  18:07    Epay
# 2      9183.6         4   1836.72   38571.12 2019-03-09  17:03    Cash
# 3     33739.2         6  10121.76  212556.96 2019-01-15  16:19    Cash
# 4     14508.0         2   1450.80   30466.80 2019-03-11  15:30    Epay
#
#        cogs  gross margin percentage  gross income  Rating
# 0   59227.2                 4.761905       2961.36     5.9
# 1   20851.2                 4.761905       1042.56     4.5
# 2   36734.4                 4.761905       1836.72     6.8
# 3  202435.2                 4.761905      10121.76     4.5
# 4   29016.0                 4.761905       1450.80     4.4

# %%
df['Date'].head()
# Out:
# 0   2019-02-20
# 1   2019-02-06
# 2   2019-03-09
# 3   2019-01-15
# 4   2019-03-11
# Name: Date, dtype: datetime64[ns]

# %%
print(df['Date'].dtype)
# Out:
# datetime64[ns]

# %%
df['Date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1000 entries, 0 to 999
# Series name: Date
# Non-Null Count  Dtype
# --------------  -----
# 1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 7.9 KB

# %% [markdown]
# Accurate conversion of the time column & prints appropriate data type

# %%
#Convert the Time from object to datetime
df["Time"] = pd.to_datetime(df["Time"])  
df.head()
# Out:
#     Invoice ID Branch   City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1  351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2  529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3  299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4  319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
#
#    Unit price  Quantity    Tax 5%      Total       Date                Time  \
# 0     19742.4         3   2961.36   62188.56 2019-02-20 2023-05-06 13:27:00
# 1      5212.8         4   1042.56   21893.76 2019-02-06 2023-05-06 18:07:00
# 2      9183.6         4   1836.72   38571.12 2019-03-09 2023-05-06 17:03:00
# 3     33739.2         6  10121.76  212556.96 2019-01-15 2023-05-06 16:19:00
# 4     14508.0         2   1450.80   30466.80 2019-03-11 2023-05-06 15:30:00
#
#   Payment      cogs  gross margin percentage  gross income  Rating
# 0    Card   59227.2                 4.761905       2961.36     5.9
# 1    Epay   20851.2                 4.761905       1042.56     4.5
# 2    Cash   36734.4                 4.761905       1836.72     6.8
# 3    Cash  202435.2                 4.761905      10121.76     4.5
# 4    Epay   29016.0                 4.761905       1450.80     4.4

# %%
#Prints appropriate data type
print(df['Time'].dtype)
# Out:
# datetime64[ns]

# %%
df['Time'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1000 entries, 0 to 999
# Series name: Time
# Non-Null Count  Dtype
# --------------  -----
# 1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 7.9 KB

# %%
#Convert the Time from object to datetime
df['Time'] = df['Time'].dt.time
df.head()
# Out:
#     Invoice ID Branch   City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1  351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2  529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3  299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4  319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
#
#    Unit price  Quantity    Tax 5%      Total       Date      Time Payment  \
# 0     19742.4         3   2961.36   62188.56 2019-02-20  13:27:00    Card
# 1      5212.8         4   1042.56   21893.76 2019-02-06  18:07:00    Epay
# 2      9183.6         4   1836.72   38571.12 2019-03-09  17:03:00    Cash
# 3     33739.2         6  10121.76  212556.96 2019-01-15  16:19:00    Cash
# 4     14508.0         2   1450.80   30466.80 2019-03-11  15:30:00    Epay
#
#        cogs  gross margin percentage  gross income  Rating
# 0   59227.2                 4.761905       2961.36     5.9
# 1   20851.2                 4.761905       1042.56     4.5
# 2   36734.4                 4.761905       1836.72     6.8
# 3  202435.2                 4.761905      10121.76     4.5
# 4   29016.0                 4.761905       1450.80     4.4

# %%
#Accurate extraction of the Day, Month, Year & Hour features

#Extract and create column for day
df['Day'] = df['Date'].dt.day
df.head()
# Out:
#     Invoice ID Branch   City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1  351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2  529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3  299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4  319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
#
#    Unit price  Quantity    Tax 5%      Total       Date      Time Payment  \
# 0     19742.4         3   2961.36   62188.56 2019-02-20  13:27:00    Card
# 1      5212.8         4   1042.56   21893.76 2019-02-06  18:07:00    Epay
# 2      9183.6         4   1836.72   38571.12 2019-03-09  17:03:00    Cash
# 3     33739.2         6  10121.76  212556.96 2019-01-15  16:19:00    Cash
# 4     14508.0         2   1450.80   30466.80 2019-03-11  15:30:00    Epay
#
#        cogs  gross margin percentage  gross income  Rating  Day
# 0   59227.2                 4.761905       2961.36     5.9   20
# 1   20851.2                 4.761905       1042.56     4.5    6
# 2   36734.4                 4.761905       1836.72     6.8    9
# 3  202435.2                 4.761905      10121.76     4.5   15
# 4   29016.0                 4.761905       1450.80     4.4   11

# %%
#Extract and create column for week
df['Week'] = df['Date'].dt.week
df.head()
# Out:
# C:\Users\Saheed\AppData\Local\Temp\ipykernel_7624\303480886.py:2: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df['Week'] = df['Date'].dt.week
#     Invoice ID Branch   City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1  351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2  529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3  299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4  319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
#
#    Unit price  Quantity    Tax 5%      Total       Date      Time Payment  \
# 0     19742.4         3   2961.36   62188.56 2019-02-20  13:27:00    Card
# 1      5212.8         4   1042.56   21893.76 2019-02-06  18:07:00    Epay
# 2      9183.6         4   1836.72   38571.12 2019-03-09  17:03:00    Cash
# 3     33739.2         6  10121.76  212556.96 2019-01-15  16:19:00    Cash
# 4     14508.0         2   1450.80   30466.80 2019-03-11  15:30:00    Epay
#
#        cogs  gross margin percentage  gross income  Rating  Day  Week
# 0   59227.2                 4.761905       2961.36     5.9   20     8
# 1   20851.2                 4.761905       1042.56     4.5    6     6
# 2   36734.4                 4.761905       1836.72     6.8    9    10
# 3  202435.2                 4.761905      10121.76     4.5   15     3
# 4   29016.0                 4.761905       1450.80     4.4   11    11

# %%
#Extract and create column for month
df['Month'] = df['Date'].dt.month
df.tail()
# Out:
#       Invoice ID Branch           City Customer type  Gender  \
# 995  148-41-7930      C  Port Harcourt        Normal    Male
# 996  189-40-5216      C  Port Harcourt        Normal    Male
# 997  267-62-7380      C  Port Harcourt        Member    Male
# 998  652-49-6720      C  Port Harcourt        Member  Female
# 999  233-67-5758      C  Port Harcourt        Normal    Male
#
#                Product line  Unit price  Quantity    Tax 5%      Total  \
# 995       Health and beauty     35985.6         7  12594.96  264494.16
# 996  Electronic accessories     34693.2         7  12142.62  254995.02
# 997  Electronic accessories     29642.4        10  14821.20  311245.20
# 998  Electronic accessories     21942.0         1   1097.10   23039.10
# 999       Health and beauty     14526.0         1    726.30   15252.30
#
#           Date      Time Payment      cogs  gross margin percentage  \
# 995 2019-01-23  10:33:00    Cash  251899.2                 4.761905
# 996 2019-01-09  11:40:00    Cash  242852.4                 4.761905
# 997 2019-03-29  19:12:00    Epay  296424.0                 4.761905
# 998 2019-02-18  11:40:00    Epay   21942.0                 4.761905
# 999 2019-01-29  13:46:00    Epay   14526.0                 4.761905
#
#      gross income  Rating  Day  Week  Month
# 995      12594.96     6.1   23     4      1
# 996      12142.62     6.0    9     2      1
# 997      14821.20     4.3   29    13      3
# 998       1097.10     5.9   18     8      2
# 999        726.30     6.2   29     5      1

# %%
#Extract and create column for year
df['Year'] = df['Date'].dt.year
df.head()
# Out:
#     Invoice ID Branch   City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1  351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2  529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3  299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4  319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
#
#    Unit price  Quantity    Tax 5%      Total  ...      Time Payment      cogs  \
# 0     19742.4         3   2961.36   62188.56  ...  13:27:00    Card   59227.2
# 1      5212.8         4   1042.56   21893.76  ...  18:07:00    Epay   20851.2
# 2      9183.6         4   1836.72   38571.12  ...  17:03:00    Cash   36734.4
# 3     33739.2         6  10121.76  212556.96  ...  16:19:00    Cash  202435.2
# 4     14508.0         2   1450.80   30466.80  ...  15:30:00    Epay   29016.0
#
#    gross margin percentage  gross income  Rating  Day  Week  Month  Year
# 0                 4.761905       2961.36     5.9   20     8      2  2019
# 1                 4.761905       1042.56     4.5    6     6      2  2019
# 2                 4.761905       1836.72     6.8    9    10      3  2019
# 3                 4.761905      10121.76     4.5   15     3      1  2019
# 4                 4.761905       1450.80     4.4   11    11      3  2019
#
# [5 rows x 21 columns]

# %%
#df["Hour"] = df["Time"].dt.hour

# %%
#The numbers of unique hours of sales in the supermarket are accurately determined.
#df["Hour"].unique()

# %%
#Result that shows an array that contains the unique sales hours.
#df["Hour"].nunique()

# %%
#Extraction of Month
df['Date'].dt.month_name()
# Out:
# 0      February
# 1      February
# 2         March
# 3       January
# 4         March
#          ...
# 995     January
# 996     January
# 997       March
# 998    February
# 999     January
# Name: Date, Length: 1000, dtype: object

# %%
#Extraction of the Day
df['Date'].dt.day_name()
# Out:
# 0      Wednesday
# 1      Wednesday
# 2       Saturday
# 3        Tuesday
# 4         Monday
#          ...
# 995    Wednesday
# 996    Wednesday
# 997       Friday
# 998       Monday
# 999      Tuesday
# Name: Date, Length: 1000, dtype: object

# %% [markdown]
# ### Step 4 - Unique Values in Columns
# - Appropriate method to generate the unique values in the categorical columns (apart from the example - Branch column).
# - Generated the count figure of the categorical values using the value_counts() method.

# %%
#Appropriate method to generate the unique values in the categorical columns (apart from the example - Branch column).
print(df.columns)
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating', 'Day', 'Week', 'Month', 'Year'],
#       dtype='object')

# %%
for i in df.columns:
    print(i)
# Out:
# Invoice ID
# Branch
# City
# Customer type
# Gender
# Product line
# Unit price
# Quantity
# Tax 5%
# Total
# Date
# Time
# Payment
# cogs
# gross margin percentage
# gross income
# Rating
# Day
# Week
# Month
# Year

# %%
for i in df.columns:
    if df[i].dtype == 'object':
        print(i)
# Out:
# Invoice ID
# Branch
# City
# Customer type
# Gender
# Product line
# Time
# Payment

# %%
result = [i for i in df.columns if df[i].dtype == 'object']
result
# Out:
# ['Invoice ID',
#  'Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Time',
#  'Payment']

# %%
df['Branch'].unique().tolist()
# Out:
# ['B', 'A', 'C']

# %%
df['Branch'].value_counts()
# Out:
# A    340
# B    332
# C    328
# Name: Branch, dtype: int64

# %%
print("Total Number of Unique values in the Branch Column : {}". format(len(df['Branch'].unique().tolist())))
# Out:
# Total Number of Unique values in the Branch Column : 3

# %%
#List of methods of payment
print(df['Payment'].unique())
#Or
op = [pay for pay in df['Payment'].unique()]
print(op)
# Out:
# ['Card' 'Epay' 'Cash']
# ['Card', 'Epay', 'Cash']

# %%
count = 0 
for i in df['Payment'].unique():
    print(i)
    count += 1
print('There are only {} methods of payment'.format(count))
# Out:
# Card
# Epay
# Cash
# There are only 3 methods of payment

# %%
#Generated the count figure of the categorical values using the value_counts() method
df['Branch'].value_counts()
# Out:
# A    340
# B    332
# C    328
# Name: Branch, dtype: int64

# %%
df['City'].value_counts()
# Out:
# Lagos            340
# Abuja            332
# Port Harcourt    328
# Name: City, dtype: int64

# %%
df['Customer type'].value_counts()
# Out:
# Member    501
# Normal    499
# Name: Customer type, dtype: int64

# %%
print(df['Customer type'].unique())
# Out:
# ['Member' 'Normal']

# %%
count = 0 
for i in df['Customer type'].unique():
    print(i)
    count += 1
print('There are only {} types of Customer'.format(count))
# Out:
# Member
# Normal
# There are only 2 types of Customer

# %%
print(df['Customer type'].nunique())
# Out:
# 2

# %%
print(df['Product line'].unique())
# Out:
# ['Food and beverages' 'Fashion accessories' 'Electronic accessories'
#  'Sports and travel' 'Home and lifestyle' 'Health and beauty']

# %%
print(df['Product line'].nunique())
# Out:
# 6

# %%
count = 0
for i in df['Product line'].unique():
    print(i)
    count = count + 1
print('There are only {} product lines in the dataset'.format(count))
# Out:
# Food and beverages
# Fashion accessories
# Electronic accessories
# Sports and travel
# Home and lifestyle
# Health and beauty
# There are only 6 product lines in the dataset

# %%
#print(df.value_counts())

# %%
for i in result:
    if i != 'Invoice ID':
        print ("For {} Coulmns".format(i))
        print ("Total Number of unique value: {}". format(len(df[i].unique().tolist())))
        print('********************************')
# Out:
# For Branch Coulmns
# Total Number of unique value: 3
# ********************************
# For City Coulmns
# Total Number of unique value: 3
# ********************************
# For Customer type Coulmns
# Total Number of unique value: 2
# ********************************
# For Gender Coulmns
# Total Number of unique value: 2
# ********************************
# For Product line Coulmns
# Total Number of unique value: 6
# ********************************
# For Time Coulmns
# Total Number of unique value: 506
# ********************************
# For Payment Coulmns
# Total Number of unique value: 3
# ********************************

# %% [markdown]
# ### Step 5 - Aggregation with GroupBy
# - A groupby object with the "City Column", and aggregation function of sum and mean.
# - A table that shows the gross income of each city, and determines the city with the highest total gross income.
# - Optional - Use of appropriate methods & descriptions to explore other columns such as Unit Price, Quantity.

# %%
df.groupby('City').agg(['sum', 'mean', 'count'])
# Out:
# C:\Users\Saheed\AppData\Local\Temp\ipykernel_7624\571294906.py:1: FutureWarning: ['Invoice ID', 'Branch', 'Customer type', 'Gender', 'Product line', 'Date', 'Time', 'Payment'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.groupby('City').agg(['sum', 'mean', 'count'])
#               Unit price                     Quantity                  \
#                      sum          mean count      sum      mean count
# City
# Abuja          6652396.8  20037.339759   332     1820  5.481928   332
# Lagos          6705176.4  19721.107059   340     1859  5.467647   340
# Port Harcourt  6684393.6  20379.248780   328     1831  5.582317   328
#
#                    Tax 5%                           Total  ...   Day  Week  \
#                       sum         mean count          sum  ... count   sum
# City                                                       ...
# Abuja          1820531.52  5483.528675   332  38231161.92  ...   332  2340
# Lagos          1820577.78  5354.640529   340  38232133.38  ...   340  2426
# Port Harcourt  1895463.54  5778.852256   328  39804734.34  ...   328  2230
#
#                               Month                    Year
#                    mean count   sum      mean count     sum    mean count
# City
# Abuja          7.048193   332   665  2.003012   332  670308  2019.0   332
# Lagos          7.135294   340   688  2.023529   340  686460  2019.0   340
# Port Harcourt  6.798780   328   640  1.951220   328  662232  2019.0   328
#
# [3 rows x 36 columns]

# %% [markdown]
# There are only 3 columns and 24 columns

# %%
#A table that shows the gross income of each city 

# Get the sum of the durations per month
df.groupby('City')['gross income'].sum().reset_index()
# Out:
#             City  gross income
# 0          Abuja    1820531.52
# 1          Lagos    1820577.78
# 2  Port Harcourt    1895463.54

# %% [markdown]
# Comment:
# * Port Harcout has the highest sum of gross income follow by Lagos and the least among them is Abuja

# %%
#Getting the city with the highest gross income 
#gross_city.max().reset_index()
df.groupby('City')['gross income'].max().reset_index()
# Out:
#             City  gross income
# 0          Abuja       17528.4
# 1          Lagos       17816.4
# 2  Port Harcourt       17874.0

# %% [markdown]
# Comment:
# * Port Harcout has the highest gross income follow by Lagos and the least among them is Abuja

# %%
#Extract the each city with the least gross income 
df.groupby('City')['gross income'].min().reset_index()
# Out:
#             City  gross income
# 0          Abuja        319.50
# 1          Lagos        217.62
# 2  Port Harcourt        183.06

# %% [markdown]
# Comment:
# * Port Harcourt has the least gross income follow by Lagos and the least among them is Abuja

# %%
df.groupby('City')['gross margin percentage'].sum().reset_index()
# Out:
#             City  gross margin percentage
# 0          Abuja              1580.952381
# 1          Lagos              1619.047619
# 2  Port Harcourt              1561.904762

# %% [markdown]
# Comment:
# * Lagos has the highest sum of gross margin percentage follow by Abuja, then Port Harcourt

# %%
#Extract the city with the average gross income 
df.groupby('City')['gross margin percentage'].mean().reset_index()
# Out:
#             City  gross margin percentage
# 0          Abuja                 4.761905
# 1          Lagos                 4.761905
# 2  Port Harcourt                 4.761905

# %%
#The total amount of sales and average sales amount per invoice at each branch

# %%
df[['Branch', 'Total']].groupby('Branch').agg(['mean','sum','count'])
# Out:
#                 Total
#                  mean          sum count
# Branch
# A       112447.451118  38232133.38   340
# B       115154.102169  38231161.92   332
# C       121355.897378  39804734.34   328

# %% [markdown]
# * The average amount per invoice is higher in the C branch. Therefore, the total sales amount of this branch C is higher than the other branches less number of invoices.

# %%
#check the average unit price of products in each product line.
df[['Product line', 'Unit price']].groupby('Product line').mean().sort_values(by='Unit price', ascending=False).round(2)
# Out:
#                         Unit price
# Product line
# Fashion accessories       20575.31
# Sports and travel         20517.57
# Food and beverages        20163.19
# Home and lifestyle        19914.10
# Health and beauty         19747.61
# Electronic accessories    19278.57

# %% [markdown]
# * Fashion accessories lead the list and the average unit prices are quite close to each other

# %%
#check the trend in weekly sales amounts 
df[['Date', 'Total']].groupby('Date').sum().head()
# Out:
#                  Total
# Date
# 2019-01-01  1708265.16
# 2019-01-02   700381.08
# 2019-01-03   748126.26
# 2019-01-04   584527.86
# 2019-01-05  1273206.06

# %%
#Extract the trend in weekly with highest sales amounts 
df[['Date', 'Total']].groupby('Date').sum().max().head()
# Out:
# Total    2690656.92
# dtype: float64

# %%
#Extract the city with the highest gross income 
df.groupby('City')['gross income'].sum().reset_index().max().reset_index()
# Out:
#           index              0
# 0          City  Port Harcourt
# 1  gross income     1895463.54

# %%
#Extract city with the least month
df.groupby('City')['Date'].min().reset_index()
# Out:
#             City       Date
# 0          Abuja 2019-01-01
# 1          Lagos 2019-01-01
# 2  Port Harcourt 2019-01-01

# %%
#Extract city with the highest month
df.groupby('City')['Date'].max().reset_index()
# Out:
#             City       Date
# 0          Abuja 2019-03-30
# 1          Lagos 2019-03-30
# 2  Port Harcourt 2019-03-30

# %%
#Extract city with the least hour
df.groupby('City')['Time'].min().reset_index()
# Out:
#             City      Time
# 0          Abuja  10:01:00
# 1          Lagos  10:00:00
# 2  Port Harcourt  10:00:00

# %%
#Extract city with the least hour
df.groupby('City')['Time'].max().reset_index()
# Out:
#             City      Time
# 0          Abuja  20:57:00
# 1          Lagos  20:59:00
# 2  Port Harcourt  20:59:00

# %%
#Extract City base on Unit price, gross income, Quantity and gross margin percentage
df.groupby('City')[['Unit price', 'gross income', 'Quantity', 'gross margin percentage']].sum()
# Out:
#                Unit price  gross income  Quantity  gross margin percentage
# City
# Abuja           6652396.8    1820531.52      1820              1580.952381
# Lagos           6705176.4    1820577.78      1859              1619.047619
# Port Harcourt   6684393.6    1895463.54      1831              1561.904762

# %% [markdown]
# Comment:
# * Lagos has the highest Unit price, quantity and gross margin percentage
# * Port Harcourt has the highest gross income and least gross margin percentage
# * Abuja has the least Unit price and quantity

# %%
#Extract City that has the highest base on Unit price, gross income, Quantity and gross margin percentage
df.groupby('City')[['Unit price', 'gross income', 'Quantity', 'gross margin percentage']].sum().max().reset_index()
# Out:
#                      index             0
# 0               Unit price  6.705176e+06
# 1             gross income  1.895464e+06
# 2                 Quantity  1.859000e+03
# 3  gross margin percentage  1.619048e+03

# %%
#Product line with the highest gross income
df[['Product line', 'gross income']].groupby('Product line').sum().reset_index().sort_values(['gross income'], ascending =False)
# Out:
#              Product line  gross income
# 2      Food and beverages     962483.04
# 5       Sports and travel     944962.74
# 0  Electronic accessories     931500.54
# 1     Fashion accessories     930958.20
# 4      Home and lifestyle     923347.08
# 3       Health and beauty     843321.24

# %% [markdown]
# Comment:
# * Food and beverages has the highest gross income while Health and beauty has the least gross income

# %%
#Extract the city with the highest unit price
df.groupby('City')['Unit price', 'Date'].max()
# Out:
# C:\Users\Saheed\AppData\Local\Temp\ipykernel_7624\1259646932.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('City')['Unit price', 'Date'].max()
#                Unit price       Date
# City
# Abuja             35985.6 2019-03-30
# Lagos             35938.8 2019-03-30
# Port Harcourt     35985.6 2019-03-30

# %%
#Extract the city with the least unit price
df.groupby('City')['Unit price', 'Date'].min()
# Out:
# C:\Users\Saheed\AppData\Local\Temp\ipykernel_7624\1617604091.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('City')['Unit price', 'Date'].min()
#                Unit price       Date
# City
# Abuja              3812.4 2019-01-01
# Lagos              3628.8 2019-01-01
# Port Harcourt      3657.6 2019-01-01

# %%
#calculate the standard deviation for each of the city
df.groupby('City')['Unit price', 'Time'].std()
# Out:
# C:\Users\Saheed\AppData\Local\Temp\ipykernel_7624\1498154333.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('City')['Unit price', 'Time'].std()
# C:\Users\Saheed\AppData\Local\Temp\ipykernel_7624\1498154333.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('City')['Unit price', 'Time'].std()
#                 Unit price
# City
# Abuja          9440.841216
# Lagos          9407.565699
# Port Harcourt  9784.727668

# %% [markdown]
# ### Transpose

# %%
# Transpose indexes and columns
df.transpose().head()
# Out:
#                        0            1            2            3    \
# Invoice ID     692-92-5582  351-62-0822  529-56-3974  299-46-1805
# Branch                   B            B            B            B
# City                 Abuja        Abuja        Abuja        Abuja
# Customer type       Member       Member       Member       Member
# Gender              Female       Female         Male       Female
#
#                        4            5            6            7    \
# Invoice ID     319-50-3348  371-85-5789  273-16-6619  649-29-6775
# Branch                   B            B            B            B
# City                 Abuja        Abuja        Abuja        Abuja
# Customer type       Normal       Normal       Normal       Normal
# Gender              Female         Male         Male         Male
#
#                        8            9    ...            990            991  \
# Invoice ID     145-94-9061  871-79-8483  ...    867-47-1948    256-58-3609
# Branch                   B            B  ...              C              C
# City                 Abuja        Abuja  ...  Port Harcourt  Port Harcourt
# Customer type       Normal       Normal  ...         Normal         Member
# Gender              Female         Male  ...         Female           Male
#
#                          992            993            994            995  \
# Invoice ID       364-34-2972    744-82-9138    728-47-9078    148-41-7930
# Branch                     C              C              C              C
# City           Port Harcourt  Port Harcourt  Port Harcourt  Port Harcourt
# Customer type         Member         Normal         Member         Normal
# Gender                  Male           Male           Male           Male
#
#                          996            997            998            999
# Invoice ID       189-40-5216    267-62-7380    652-49-6720    233-67-5758
# Branch                     C              C              C              C
# City           Port Harcourt  Port Harcourt  Port Harcourt  Port Harcourt
# Customer type         Normal         Member         Member         Normal
# Gender                  Male           Male         Female           Male
#
# [5 rows x 1000 columns]

# %% [markdown]
# ### Step 6 - Data Visualization
# - Appropriate use of countplot to determine the branch with the highest sales record.
# - Optional - Appropriate use of countplot to determine the most used payment method & city with the most sales.
# - Appropriate use of countplot to determine the highest & lowest sold product line.
# - Result that shows the Payment channel used by most customers to pay for each product line. Chart should also show the "product line" column on the Y-axis, and the "hue" parameter for the "Payment" column.

# %%
#Appropriate use of countplot to determine the branch with the highest sales record

sns.countplot(x='Branch', hue='City', data = df, palette = 'Set2').set_title('Branch with Sales', size=15);

# %%
sns.countplot(x= 'Branch', data = df).set_title("Branch vs Sales", size = 24);

# %%
#Plotting bar horizontal base on Card Payment
sns.countplot(y='Branch', hue='City', data=df).set_title('Card Payment', size=15);

# %%
#payment method & city
sns.countplot(x='Payment', hue='Payment', data=df, palette = "Set3").set_title('Card Payment', size=15);

# %%
#payment method & city
sns.countplot(x='Payment', data=df, palette = "Set1").set_title('Card Payment', size=25);

# %% [markdown]
# Comment:
#    * Both the Epay Payment and Cash has the highest Caed Payment

# %%
#highest & lowest sold product line.
sns.countplot(y='Product line', data=df, palette='Spectral_r', saturation = 0.9).set_title('Sale and its Product Lines', size=20)
# Out:
# Text(0.5, 1.0, 'Sale and its Product Lines')

# %% [markdown]
# Comments:
# * Fashion accessories is the highest product line with value 175 and Health and beauty is the least with value around 152

# %%
#highest & lowest sold product line.
sns.countplot(y='Product line', hue='Payment', data=df, palette='Spectral_r', saturation = 0.9).set_title('Payment Method and its Product Lines', size=20)
# Out:
# Text(0.5, 1.0, 'Payment Method and its Product Lines')

# %%
#payment method & city with the most sales.
sns.countplot(x='Payment', data=df, hue='City').set_title('Payment Method and City', size=24)
# Out:
# Text(0.5, 1.0, 'Payment Method and City')

# %%
#Payment method and branch
sns.countplot(x='Payment', data=df, hue='Branch').set_title('Payment Method and Branch', size=24)
# Out:
# Text(0.5, 1.0, 'Payment Method and Branch')

# %%
#Visualize the count of branch per year with a plot
sns.countplot(data=df, x = 'Year')
# Out:
# <Axes: xlabel='Year', ylabel='count'>

# %%
#Extract the distribution of the total sales amount of purchases using histogram
df.Total.plot(kind='hist', figsize=(8,5), title='Histogram of Total Sale Amounts')
# Out:
# <Axes: title={'center': 'Histogram of Total Sale Amounts'}, ylabel='Frequency'>

# %%
#Plot histogram to show the 3 cities
sns.histplot(data=df, x = 'City')
plt.title('Histogram of the 3 Cities')
# Out:
# Text(0.5, 1.0, 'Histogram of the 3 Cities')

# %%
#Histogram to show the methods of payment
sns.histplot(data=df, x = 'Payment')
plt.title('Histogram for the Methods of Payment')
# Out:
# Text(0.5, 1.0, 'Histogram for the Methods of Payment')

# %% [markdown]
# Epay has the highest payment and the most popular method of payment

# %%
plt.figure(figsize=(10, 4), dpi=200)
sns.histplot(data=df, x = 'gross income', kde=True, bins=25)
plt.title('Gross Income Histogram Result')
# Out:
# Text(0.5, 1.0, 'Gross Income Histogram Result')

# %%
#Histogram for quantity
sns.histplot(data=df, x = 'Quantity')
plt.title('Histogram for the Quantity')
# Out:
# Text(0.5, 1.0, 'Histogram for the Quantity')

# %%
sns.histplot(data=df, x = 'Gender', hue = 'Gender')
plt.title('Gender')
plt.title('Histogram of the Gender')
# Out:
# Text(0.5, 1.0, 'Histogram of the Gender')

# %%
# Create a function that we can re-use
def show_distribution(var_data):
    '''
    This function will make a distribution (graph) and display it
    '''
    # Get statistics
    min_val = var_data.min()
    max_val = var_data.max()
    mean_val = var_data.mean()
    med_val = var_data.median()
    mod_val = var_data.mode()[0]

    print('Minimum:{:.2f}\nMean:{:.2f}\nMedian:{:.2f}\nMode:{:.2f}\nMaximum:{:.2f}\n'.format(min_val,
                                                                                            mean_val,
                                                                                            med_val,
                                                                                            mod_val,
                                                                                            max_val))
    # Create a figure for 2 subplots (2 rows, 1 column)
    fig, ax = plt.subplots(2, 1, figsize = (10, 4))
    
    # Plot the histogram 
    ax[0].hist(var_data)
    ax[0].set_ylabel('Frequency')
    
    # Add lines for the mean, median, and mode
    ax[0].axvline(x=min_val, color = 'gray', linestyle='dashed', linewidth = 2)
    ax[0].axvline(x=mean_val, color = 'cyan', linestyle='dashed', linewidth = 2)
    ax[0].axvline(x=med_val, color = 'red', linestyle='dashed', linewidth = 2)
    ax[0].axvline(x=mod_val, color = 'yellow', linestyle='dashed', linewidth = 2)
    ax[0].axvline(x=max_val, color = 'gray', linestyle='dashed', linewidth = 2)

    # Plot the boxplot 
    ax[1].boxplot(var_data, vert=False)
    ax[1].set_xlabel('Value')
    
    # Add a title to the Figure
    fig.suptitle('Data Distribution')
    
    # Show the figure
    fig.show()

show_distribution(df['gross income'])
# Out:
# Minimum:183.06
# Mean:5536.57
# Median:4351.68
# Mode:1495.44
# Maximum:17874.00
# C:\Users\Saheed\AppData\Local\Temp\ipykernel_7624\2758081578.py:40: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
col = df['Unit price']
# Call the function
show_distribution(col)
# Out:
# Minimum:3628.80
# Mean:20041.97
# Median:19882.80
# Mode:30157.20
# Maximum:35985.60
# C:\Users\Saheed\AppData\Local\Temp\ipykernel_7624\2758081578.py:40: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
#Plot scatter plot between cogs and Unit price
sns.scatterplot(x = 'Unit price', y = 'cogs', hue = 'City', data = df)
# Out:
# <Axes: xlabel='Unit price', ylabel='cogs'>

# %% [markdown]
# Comments:
# * Unit price is directly proportional as cogs
# * As the Unit price increases, corrresponding value of cogs also increases
# * From the graph, Port harcourt has highest Unit price which is above 35000$ and highest cogs above 350000

# %%
# Plot the pairplot
sns.pairplot(df, vars=['gross margin percentage', 'gross income', 'cogs', 'Rating'])

# %% [markdown]
# #### Visualizing Correlation

# %%
df.corr()
# Out:
# C:\Users\Saheed\AppData\Local\Temp\ipykernel_7624\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                          Unit price  Quantity    Tax 5%     Total      cogs  \
# Unit price                 1.000000  0.010778  0.633962  0.633962  0.633962
# Quantity                   0.010778  1.000000  0.705510  0.705510  0.705510
# Tax 5%                     0.633962  0.705510  1.000000  1.000000  1.000000
# Total                      0.633962  0.705510  1.000000  1.000000  1.000000
# cogs                       0.633962  0.705510  1.000000  1.000000  1.000000
# gross margin percentage         NaN       NaN       NaN       NaN       NaN
# gross income               0.633962  0.705510  1.000000  1.000000  1.000000
# Rating                    -0.008778 -0.015815 -0.036442 -0.036442 -0.036442
# Day                        0.057021 -0.043347 -0.002515 -0.002515 -0.002515
# Week                      -0.005908 -0.033794 -0.025893 -0.025893 -0.025893
# Month                     -0.027387 -0.014524 -0.022301 -0.022301 -0.022301
# Year                            NaN       NaN       NaN       NaN       NaN
#
#                          gross margin percentage  gross income    Rating  \
# Unit price                                   NaN      0.633962 -0.008778
# Quantity                                     NaN      0.705510 -0.015815
# Tax 5%                                       NaN      1.000000 -0.036442
# Total                                        NaN      1.000000 -0.036442
# cogs                                         NaN      1.000000 -0.036442
# gross margin percentage                      NaN           NaN       NaN
# gross income                                 NaN      1.000000 -0.036442
# Rating                                       NaN     -0.036442  1.000000
# Day                                          NaN     -0.002515 -0.007076
# Week                                         NaN     -0.025893 -0.042287
# Month                                        NaN     -0.022301 -0.042880
# Year                                         NaN           NaN       NaN
#
#                               Day      Week     Month  Year
# Unit price               0.057021 -0.005908 -0.027387   NaN
# Quantity                -0.043347 -0.033794 -0.014524   NaN
# Tax 5%                  -0.002515 -0.025893 -0.022301   NaN
# Total                   -0.002515 -0.025893 -0.022301   NaN
# cogs                    -0.002515 -0.025893 -0.022301   NaN
# gross margin percentage       NaN       NaN       NaN   NaN
# gross income            -0.002515 -0.025893 -0.022301   NaN
# Rating                  -0.007076 -0.042287 -0.042880   NaN
# Day                      1.000000  0.231182 -0.118996   NaN
# Week                     0.231182  1.000000  0.935013   NaN
# Month                   -0.118996  0.935013  1.000000   NaN
# Year                          NaN       NaN       NaN   NaN

# %%
# Strong correlation 
sns.heatmap(df.corr(), vmin = -1, vmax = 1, annot=True)
# Out:
# C:\Users\Saheed\AppData\Local\Temp\ipykernel_7624\4207140107.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), vmin = -1, vmax = 1, annot=True)
# <Axes: >

# %%
# Create a Figure
fig = plt.figure(figsize=(8, 3))

# Create a bar plot of name vs grade
plt.bar(x=df.Gender, height=df.cogs, color='orange')

# Customize the chart
plt.title('Bar Chart')
plt.xlabel('City')
plt.ylabel('Cogs')
plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.xticks(rotation=99)
plt.show()

# %%
# Create a Figure
fig = plt.figure(figsize=(8, 3))

# Create a bar plot of name vs grade
plt.bar(x=df.Gender, height=df.Quantity, color='orange')

# Customize the chart
plt.title('Bar Chart')
plt.xlabel('Gender')
plt.ylabel('Quantity')
plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.xticks(rotation=90)
plt.show()

# %%
# Create a Figure
fig = plt.figure(figsize=(8, 3))

# Create a bar plot of name vs grade
plt.bar(x=df.Gender, height=df.Rating, color='orange')

# Customize the chart
plt.title('Bar Chart')
plt.xlabel('Gender')
plt.ylabel('Rating')
plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.xticks(rotation=99)
plt.show()

# %%
sns.countplot(x = 'City', hue = 'Gender', data = df).set_title("Gender VS City")
# Out:
# Text(0.5, 1.0, 'Gender VS City')

# %% [markdown]
# #### Swarmplot of the 3 Cities

# %%
sns.catplot(y = 'gross income', x = 'City', kind = 'swarm', data = df, aspect = 4, hue='Gender', dodge=True);
plt.title('Swarmplot for 3 Cities')
# Out:
# Text(0.5, 1.0, 'Swarmplot for 3 Cities')

# %% [markdown]
# * In Abuja female customers have more gross income than males with little difference
# * In Lagos state, male customers had more gross income than the females with little difference
# * No much difference in gross income between the gender in Port Harcourt

# %% [markdown]
# ### Box Plot

# %%
# Get the variable to examine

var = df['Unit price']

# Create a Figure
fig = plt.figure(figsize=(10,4))

# Plot a histogram
plt.boxplot(var)

# Add titles and labels
plt.title('Data Distribution')

# Show the figure
fig.show()
# Out:
# C:\Users\Saheed\AppData\Local\Temp\ipykernel_7624\2180611942.py:15: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
plt.figure(figsize = (10, 4), dpi = 200)
sns.boxplot(data = df, y='gross income', x = 'City')
plt.title('BoxPlot fo the Cities')
# Out:
# Text(0.5, 1.0, 'BoxPlot fo the Cities')

# %% [markdown]
# * In terms of gross income, the range in Port Harcourt is the highest above 17500 while the range for Abuja and Lagos is below 17500 that means the data in Port Harcourt is a little bit spread out
# * The minimum gross income for each city is 500 that is they have equal minimum gross income
# * The maximum gross income of cities abuja and lagos is the same 15000 but below 17500 while that of Port Harcourt is above 17500
# * Lower quartile Q1: 25% of the customers in both Abuja and Port Harcourt had less than 2500 gross income while Lagos has 2500 as gross income
# * Upper quartile Q3: 75% of customers in Port Harcourt earned the highest gross income equal to more than 8500 while customers in Abuja and Lagos earned 8000
# * Higher outlier for city Abuja and city Lagos is more than 15000
# * No Lower outlier for all the 3 cities
# * Upper Outlier = Q3 + (1.5 * IQR)
# * Lower Outlier = Q1 - (1.5 * IQR)
# * IQR means Interquartile range

# %%
plt.figure(figsize = (10, 4), dpi = 200)
sns.boxplot(data = df, y='gross income', x = 'Quantity', hue = 'City')
plt.title('BoxPlot fo the Cities')
# Out:
# Text(0.5, 1.0, 'BoxPlot fo the Cities')

# %% [markdown]
# * As the gross income increases, the  Quantity also increases for all three cities

# %%
plt.figure(figsize = (10, 4), dpi = 200)
sns.boxplot(data = df, y='gross income', x = 'Payment', hue = 'City')
plt.legend(bbox_to_anchor=(1.05, 0.5))
plt.title('BoxPlot fo the Payment')
# Out:
# Text(0.5, 1.0, 'BoxPlot fo the Payment')

# %%
plt.figure(figsize = (10, 4), dpi = 200)
sns.boxplot(data = df, y='gross income', x = 'Payment', hue = 'Gender')
plt.legend(bbox_to_anchor=(1.05, 0.5))

# %%
def show_density(var_data):
    from matplotlib import pyplot as plt

    fig = plt.figure(figsize=(10,4))

    # Plot density
    var_data.plot.density()

    # Add titles and labels
    plt.title('Data Density')

    # Show the mean, median, and mode
    plt.axvline(x=var_data.mean(), color = 'cyan', linestyle='dashed', linewidth = 2)
    plt.axvline(x=var_data.median(), color = 'red', linestyle='dashed', linewidth = 2)
    plt.axvline(x=var_data.mode()[0], color = 'yellow', linestyle='dashed', linewidth = 2)

    # Show the figure
    plt.show()

# Get the density of Grade
col = df['Unit price']
show_density(col)

# %%
#Extract infomation between 80th and 85th
df.iloc[80:85]
# Out:
#      Invoice ID Branch   City Customer type  Gender            Product line  \
# 80  376-02-8238      B  Abuja        Normal    Male      Home and lifestyle
# 81  866-05-7563      B  Abuja        Member  Female  Electronic accessories
# 82  785-13-7708      B  Abuja        Normal    Male      Food and beverages
# 83  845-51-0542      B  Abuja        Member    Male      Food and beverages
# 84  110-48-7033      B  Abuja        Member    Male     Fashion accessories
#
#     Unit price  Quantity    Tax 5%      Total  ...      Time Payment  \
# 80     33793.2         8  13517.28  283862.88  ...  18:42:00    Card
# 81     29304.0         3   4395.60   92307.60  ...  19:43:00    Cash
# 82     26301.6         7   9205.56  193316.76  ...  19:06:00    Card
# 83     16758.0         9   7541.10  158363.10  ...  15:34:00    Epay
# 84     11743.2         4   2348.64   49321.44  ...  14:12:00    Cash
#
#         cogs  gross margin percentage  gross income  Rating  Day  Week  Month  \
# 80  270345.6                 4.761905      13517.28     8.3    2     5      2
# 81   87912.0                 4.761905       4395.60     4.8    9     6      2
# 82  184111.2                 4.761905       9205.56     4.2   14     3      1
# 83  150822.0                 4.761905       7541.10     6.4    2     5      2
# 84   46972.8                 4.761905       2348.64     9.0   29     5      1
#
#     Year
# 80  2019
# 81  2019
# 82  2019
# 83  2019
# 84  2019
#
# [5 rows x 21 columns]

# %%
#Extract only information of 2nd, 900th and 71th

df.iloc[[2, 900, 71]]
# Out:
#       Invoice ID Branch           City Customer type Gender  \
# 2    529-56-3974      B          Abuja        Member   Male
# 900  266-20-6657      C  Port Harcourt        Member   Male
# 71   239-36-3640      B          Abuja        Normal   Male
#
#                Product line  Unit price  Quantity   Tax 5%      Total  ...  \
# 2    Electronic accessories      9183.6         4  1836.72   38571.12  ...
# 900      Food and beverages     19814.4         7  6935.04  145635.84  ...
# 71   Electronic accessories     16326.0         6  4897.80  102853.80  ...
#
#          Time Payment      cogs  gross margin percentage  gross income  \
# 2    17:03:00    Cash   36734.4                 4.761905       1836.72
# 900  19:39:00    Epay  138700.8                 4.761905       6935.04
# 71   13:44:00    Epay   97956.0                 4.761905       4897.80
#
#      Rating  Day  Week  Month  Year
# 2       6.8    9    10      3  2019
# 900     5.2   12    11      3  2019
# 71      6.1   31     5      1  2019
#
# [3 rows x 21 columns]

# %%
#Extract the last the information in the row
df.iloc[-1]
# Out:
# Invoice ID                         233-67-5758
# Branch                                       C
# City                             Port Harcourt
# Customer type                           Normal
# Gender                                    Male
# Product line                 Health and beauty
# Unit price                             14526.0
# Quantity                                     1
# Tax 5%                                   726.3
# Total                                  15252.3
# Date                       2019-01-29 00:00:00
# Time                                  13:46:00
# Payment                                   Epay
# cogs                                   14526.0
# gross margin percentage               4.761905
# gross income                             726.3
# Rating                                     6.2
# Day                                         29
# Week                                         5
# Month                                        1
# Year                                      2019
# Name: 999, dtype: object

# %% [markdown]
# ### Using a catplot() generate visualization for the "product line" on x-axis, quantity on the y-axis, and hue as gender.

# %%
sns.catplot(x = 'Product line', y = 'Quantity', hue='Gender', data = df, aspect = 2)

# %%
sns.catplot(x = 'Product line', y = 'Unit price',  hue='Gender', data = df, aspect = 2)

# %%
sns.catplot(y = 'Product line', data = df, hue = 'Payment')

# %% [markdown]
# ### Use of catplot() to plot Product line per unit price, and Product line per Quantity. Set the kind parameter to point.

# %%
sns.catplot(x = 'Product line', y = 'Quantity', kind= 'point', hue='Gender', data = df, aspect = 2)
sns.catplot(x = 'Product line', y = 'Unit price',  kind= 'point', hue='Gender', data = df, aspect = 2)

# %% [markdown]
# ### Use catplot() to plot Product line per unit price and set kind to boxen

# %%
sns.catplot(x = 'Product line', y = 'Unit price', hue = 'Gender', kind= 'boxen', data = df, aspect = 2)

# %% [markdown]
# ### Determine the branch with the lowest rating (use boxplot)

# %%
plt.figure(figsize = (10, 4), dpi = 200)
sns.boxplot(data = df, x='Branch', y = 'Rating', hue = 'City')
plt.legend(bbox_to_anchor=(1.05, 0.5))
plt.title('BoxPlot fo the Payment')
# Out:
# Text(0.5, 1.0, 'BoxPlot fo the Payment')

# %% [markdown]
# * Abuja branch has the lowest rating

# %% [markdown]
# ## Summary

# %% [markdown]
# I learnt how to perform Exploratory Data Analysis (EDA)
# in Python and how to use external Python libraries like Pandas, Numpy, Matplotlib, Seaborn etc.
# to conduct univariate analysis, bivariate analysis and data visualization.

# %% [markdown]
# ## Conclusion
# The main purpose of this project to demonstrate various pandas functions that help us analyze tabular data. The parameters of pandas functions are highly important as they make the functions more powerful and versatile. Thus, it is very important to know what parameters achieve. One of the things I like about pandas is that there are almost always more than one way to accomplish a task. For instance, what we have done in the project can also be done in a different way. In fact, you may challenge yourself to do the same using different functions.
